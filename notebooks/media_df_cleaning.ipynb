# %% [markdown]
# **Need df for combined articles and twitter aggregated by month**

# %%
import pandas as pd 
import numpy as np

Art=pd.read_csv('../data/raw/Aggregated_California_Env_Articles_Tweets.csv')
Art.head()
# Out:
#   year_month  article_count  rate_per_100k  mean_title_sentiment  \
# 0    2011-02            1.0       0.715017              0.028871
# 1    2011-03            1.0       0.821057              0.021148
# 2    2011-04            0.0       0.833176             -0.125413
# 3    2011-05            0.0       0.875592             -0.125413
# 4    2011-06            0.0       0.969514             -0.125413
#
#    mean_title_risk  mean_body_risk  avg_sentiment  avg_risk  \
# 0         0.000000        0.015097      -0.465573  0.047619
# 1         0.000000        0.005263      -0.012873  0.000000
# 2         0.036783        0.020489      -0.185547  0.021802
# 3         0.036783        0.020489      -0.185547  0.021802
# 4         0.036783        0.020489      -0.185547  0.021802
#
#    mean_body_sentiment  tweet_count  ...  mean_body_risk_lag1  \
# 0            -0.273456            6  ...             0.018939
# 1             0.198157            5  ...             0.015097
# ...

# %%
Art.columns
# Out:
# Index(['year_month', 'article_count', 'rate_per_100k', 'mean_title_sentiment',
#        'mean_title_risk', 'mean_body_risk', 'avg_sentiment', 'avg_risk',
#        'mean_body_sentiment', 'tweet_count', 'Precipitation',
#        'Avg Rel Hum (%)', 'Avg Wind Speed (mph)', 'Wind Run (miles)',
#        'windeventcount', 'Avg Soil Temp (F)', 'AQI_PM25', 'AQI_PM10',
#        'FIRE_Acres_Burned', 'fungicide_lbs_prd_used', 'rodent_lbs_prd_used',
#        'avg_likes', 'article_count_lag1', 'mean_title_risk_lag1',
#        'mean_body_risk_lag1', 'mean_title_sentiment_lag1',
#        'mean_body_sentiment_lag1', 'FIRE_Acres_Burned_lag1',
#        'tweet_count_lag1', 'avg_risk_lag1', 'avg_sentiment_lag1',
#        'avg_likes_lag1', 'log_rate', 'logdiff_rate'],
#       dtype='str')

# %%
Art1=Art[['year_month', 'article_count', 'rate_per_100k', 'mean_title_sentiment',
       'mean_title_risk', 'mean_body_risk', 'avg_sentiment', 'avg_risk',
       'mean_body_sentiment', 'tweet_count','avg_likes']]
Art1.head()

Art1.to_csv('Media_with_features.csv', index=False)
